# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('demo.csv')

# %%
data.head()
# Out:
#    Unnamed: 0                STATE_UT_NAME    JAN   FEB    MAR    APR    MAY  \
# 0           0  ANDAMAN And NICOBAR ISLANDS  107.3  57.9   65.2  117.0  358.5
# 1           1  ANDAMAN And NICOBAR ISLANDS   43.7  26.0   18.6   90.5  374.4
# 2           2  ANDAMAN And NICOBAR ISLANDS   32.7  15.9    8.6   53.4  343.6
# 3           3            ARUNACHAL PRADESH   42.2  80.8  176.4  358.5  306.4
# 4           4            ARUNACHAL PRADESH   33.3  79.5  105.9  216.5  323.0
#
#      JUN    JUL    AUG  ...    NOV    DEC  ANNUAL  Jan-Feb  Mar-May  Jun-Sep  \
# 0  295.5  285.0  271.9  ...  315.2  250.9  2805.2    165.2    540.7   1207.2
# 1  457.2  421.3  423.1  ...  275.8  128.3  3015.7     69.7    483.5   1757.2
# 2  503.3  465.4  460.9  ...  198.6  100.0  2913.3     48.6    405.6   1884.4
# 3  447.0  660.1  427.8  ...   34.1   29.8  3043.8    123.0    841.3   1848.5
# 4  738.3  990.9  711.2  ...   29.5   31.7  4034.7    112.8    645.4   3008.4
#
# ...

# %%
data.shape
# Out:
# (641, 22)

# %%
df = data.dropna()

# %%
df.head()
# Out:
#    Unnamed: 0                STATE_UT_NAME    JAN   FEB    MAR    APR    MAY  \
# 0           0  ANDAMAN And NICOBAR ISLANDS  107.3  57.9   65.2  117.0  358.5
# 1           1  ANDAMAN And NICOBAR ISLANDS   43.7  26.0   18.6   90.5  374.4
# 2           2  ANDAMAN And NICOBAR ISLANDS   32.7  15.9    8.6   53.4  343.6
# 3           3            ARUNACHAL PRADESH   42.2  80.8  176.4  358.5  306.4
# 4           4            ARUNACHAL PRADESH   33.3  79.5  105.9  216.5  323.0
#
#      JUN    JUL    AUG  ...    NOV    DEC  ANNUAL  Jan-Feb  Mar-May  Jun-Sep  \
# 0  295.5  285.0  271.9  ...  315.2  250.9  2805.2    165.2    540.7   1207.2
# 1  457.2  421.3  423.1  ...  275.8  128.3  3015.7     69.7    483.5   1757.2
# 2  503.3  465.4  460.9  ...  198.6  100.0  2913.3     48.6    405.6   1884.4
# 3  447.0  660.1  427.8  ...   34.1   29.8  3043.8    123.0    841.3   1848.5
# 4  738.3  990.9  711.2  ...   29.5   31.7  4034.7    112.8    645.4   3008.4
#
# ...

# %%
df.shape
# Out:
# (641, 22)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'STATE_UT_NAME', 'JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN',
#        'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC', 'ANNUAL', 'Jan-Feb',
#        'Mar-May', 'Jun-Sep', 'Oct-Dec', 'flood', 'Avg_june10days',
#        'maytojune'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 641 entries, 0 to 640
# Data columns (total 22 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      641 non-null    int64
#  1   STATE_UT_NAME   641 non-null    object
#  2   JAN             641 non-null    float64
#  3   FEB             641 non-null    float64
#  4   MAR             641 non-null    float64
#  5   APR             641 non-null    float64
#  6   MAY             641 non-null    float64
#  7   JUN             641 non-null    float64
#  8   JUL             641 non-null    float64
#  9   AUG             641 non-null    float64
#  10  SEP             641 non-null    float64
#  11  OCT             641 non-null    float64
#  12  NOV             641 non-null    float64
#  13  DEC             641 non-null    float64
#  14  ANNUAL          641 non-null    float64
#  15  Jan-Feb         641 non-null    float64
#  16  Mar-May         641 non-null    float64
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0         JAN         FEB         MAR         APR         MAY  \
# count  641.000000  641.000000  641.000000  641.000000  641.000000  641.000000
# mean   320.000000   18.355070   20.984399   30.034789   45.543214   81.535101
# std    185.185043   21.082806   27.729596   45.451082   71.556279  111.960390
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.900000
# 25%    160.000000    6.900000    7.000000    7.000000    5.000000   12.100000
# 50%    320.000000   13.300000   12.300000   12.700000   15.100000   33.900000
# 75%    480.000000   19.200000   24.100000   33.200000   48.300000   91.900000
# max    640.000000  144.500000  229.600000  367.900000  554.400000  733.700000
#
#                JUN          JUL          AUG         SEP  ...         NOV  \
# count   641.000000   641.000000   641.000000  641.000000  ...  641.000000
# mean    196.007332   326.033697   291.152262  194.609048  ...   34.117473
# ...

# %%
df.isnull()
# Out:
#      Unnamed: 0  STATE_UT_NAME    JAN    FEB    MAR    APR    MAY    JUN  \
# 0         False          False  False  False  False  False  False  False
# 1         False          False  False  False  False  False  False  False
# 2         False          False  False  False  False  False  False  False
# 3         False          False  False  False  False  False  False  False
# 4         False          False  False  False  False  False  False  False
# ..          ...            ...    ...    ...    ...    ...    ...    ...
# 636       False          False  False  False  False  False  False  False
# 637       False          False  False  False  False  False  False  False
# 638       False          False  False  False  False  False  False  False
# 639       False          False  False  False  False  False  False  False
# 640       False          False  False  False  False  False  False  False
#
#        JUL    AUG  ...    NOV    DEC  ANNUAL  Jan-Feb  Mar-May  Jun-Sep  \
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0        0
# STATE_UT_NAME     0
# JAN               0
# FEB               0
# MAR               0
# APR               0
# MAY               0
# JUN               0
# JUL               0
# AUG               0
# SEP               0
# OCT               0
# NOV               0
# DEC               0
# ANNUAL            0
# Jan-Feb           0
# Mar-May           0
# Jun-Sep           0
# Oct-Dec           0
# flood             0
# Avg_june10days    0
# maytojune         0
# dtype: int64

# %%
df.STATE_UT_NAME.unique()
# Out:
# array(['ANDAMAN And NICOBAR ISLANDS', 'ARUNACHAL PRADESH', 'ASSAM',
#        'MEGHALAYA', 'MANIPUR', 'MIZORAM', 'NAGALAND', 'TRIPURA',
#        'WEST BENGAL', 'SIKKIM', 'ORISSA', 'JHARKHAND', 'BIHAR',
#        'UTTAR PRADESH', 'UTTARANCHAL', 'HARYANA', 'CHANDIGARH', 'DELHI',
#        'PUNJAB', 'HIMACHAL', 'JAMMU AND KASHMIR', 'RAJASTHAN',
#        'MADHYA PRADESH', 'GUJARAT', 'DADAR NAGAR HAVELI', 'DAMAN AND DUI',
#        'MAHARASHTRA', 'GOA', 'CHATISGARH', 'ANDHRA PRADESH', 'TAMIL NADU',
#        'PONDICHERRY', 'KARNATAKA', 'KERALA', 'LAKSHADWEEP'], dtype=object)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'STATE_UT_NAME', 'JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN',
#        'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC', 'ANNUAL', 'Jan-Feb',
#        'Mar-May', 'Jun-Sep', 'Oct-Dec', 'flood', 'Avg_june10days',
#        'maytojune'],
#       dtype='object')

# %%
df.flood.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df.JAN.unique().mean()
# Out:
# 25.151495016611292

# %%
df.FEB.unique().mean()
# Out:
# 29.09223300970874

# %%
df.ANNUAL.unique().min()
# Out:
# 94.6

# %%
df.ANNUAL.unique().max()
# Out:
# 7229.3

# %%
df.ANNUAL.unique().mean()
# Out:
# 1324.6199661590522

# %%
df.Avg_june10days.unique()
# Out:
# array([ 98.5       , 152.4       , 167.7666667 , 149.        ,
#        246.1       ,  76.13333333, 204.9       , 124.7333333 ,
#        175.4       , 213.5       ,  94.7       , 267.3       ,
#        138.8666667 , 221.7666667 , 115.2333333 ,  97.56666667,
#        177.3666667 , 139.9       , 189.2666667 , 121.8333333 ,
#        176.1       , 109.3666667 ,  95.3       ,  85.16666667,
#        231.4333333 , 201.        , 133.6666667 ,  96.26666667,
#        215.0666667 , 274.0666667 , 121.0333333 ,  84.73333333,
#        129.4333333 , 156.8       ,  74.96666667, 208.7666667 ,
#        103.3666667 , 183.7333333 , 492.0666667 , 438.7       ,
#        177.0333333 , 113.5       , 164.2       , 217.1666667 ,
#        123.5666667 , 122.7333333 , 386.2333333 , 203.3       ,
#        116.1       , 111.        , 145.2       , 112.4333333 ,
#        140.7       , 155.9       , 116.8333333 , 145.8666667 ,
#        153.1333333 , 145.7333333 , 128.2666667 , 131.9666667 ,
# ...

# %%
df.corr()
# Out:
#                 Unnamed: 0       JAN       FEB       MAR       APR       MAY  \
# Unnamed: 0        1.000000 -0.211900 -0.332645 -0.407089 -0.461584 -0.468446
# JAN              -0.211900  1.000000  0.868628  0.688776  0.343254  0.154175
# FEB              -0.332645  0.868628  1.000000  0.899637  0.633236  0.394301
# MAR              -0.407089  0.688776  0.899637  1.000000  0.838087  0.609177
# APR              -0.461584  0.343254  0.633236  0.838087  1.000000  0.885394
# MAY              -0.468446  0.154175  0.394301  0.609177  0.885394  1.000000
# JUN              -0.301185 -0.030926  0.194324  0.362265  0.630982  0.785813
# JUL              -0.234658 -0.007617  0.141263  0.204693  0.388887  0.520490
# AUG              -0.321974  0.027202  0.153355  0.171421  0.299930  0.427825
# SEP              -0.490204  0.014375  0.211977  0.337046  0.550991  0.690867
# OCT              -0.028558  0.002580  0.184534  0.336384  0.586121  0.704970
# ...
