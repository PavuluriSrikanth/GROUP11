# %%
import pandas as pd
import numpy as np
import panel as pn
pn.extension('tabulator')
import hvplot.pandas
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_872/576318526.py in <module>
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 import panel as pn
#       4 pn.extension('tabulator')
#       5 import hvplot.pandas
#
# ModuleNotFoundError: No module named 'panel'

# %%
data = pd.read_csv('demo2.csv')

# %%
data
# Out:
#      Unnamed: 0                STATE_UT_NAME    JAN   FEB    MAR    APR  \
# 0             0  ANDAMAN And NICOBAR ISLANDS  107.3  57.9   65.2  117.0
# 1             1  ANDAMAN And NICOBAR ISLANDS   43.7  26.0   18.6   90.5
# 2             2  ANDAMAN And NICOBAR ISLANDS   32.7  15.9    8.6   53.4
# 3             3            ARUNACHAL PRADESH   42.2  80.8  176.4  358.5
# 4             4            ARUNACHAL PRADESH   33.3  79.5  105.9  216.5
# ..          ...                          ...    ...   ...    ...    ...
# 636         636                       KERALA   13.4  22.1   43.6  150.4
# 637         637                       KERALA    2.3   1.0    8.4   46.9
# 638         638                       KERALA   19.8  45.2   73.9  184.9
# 639         639                       KERALA    4.8   8.3   17.5   83.3
# 640         640                  LAKSHADWEEP   20.8  14.7   11.8   48.9
#
#        MAY    JUN     JUL    AUG  ...    NOV    DEC  ANNUAL  Jan-Feb  Mar-May  \
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'STATE_UT_NAME', 'JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN',
#        'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC', 'ANNUAL', 'Jan-Feb',
#        'Mar-May', 'Jun-Sep', 'Oct-Dec', 'flood', 'Avg_june10days',
#        'maytojune'],
#       dtype='object')

# %%
data[data['STATE_UT_NAME'] == 'ANDHRA PRADESH']
# Out:
#      Unnamed: 0   STATE_UT_NAME   JAN   FEB   MAR   APR   MAY    JUN    JUL  \
# 537         537  ANDHRA PRADESH   6.0  10.1  11.3  22.8  75.3  131.9  206.4
# 538         538  ANDHRA PRADESH   6.1  10.7   8.7  19.0  55.8  135.8  240.2
# 539         539  ANDHRA PRADESH   5.5   7.7   7.7  15.0  58.4   90.2  147.3
# 540         540  ANDHRA PRADESH   4.6   6.3   8.7  16.9  46.8  120.9  216.6
# 541         541  ANDHRA PRADESH  15.7  11.6   6.0  15.2  51.4   53.4   91.2
# 542         542  ANDHRA PRADESH   7.9   8.8  10.5  14.9  52.3   64.3   99.3
# 543         543  ANDHRA PRADESH   7.9  18.1  17.2  26.3  63.9  145.0  190.2
# 544         544  ANDHRA PRADESH   8.8  10.8  17.6  44.7  96.6  132.6  178.2
# 545         545  ANDHRA PRADESH   8.7  14.4  17.7  32.3  90.7  140.7  181.5
# 546         546  ANDHRA PRADESH   7.5   7.0  11.4  11.9  18.2  178.4  317.4
# 547         547  ANDHRA PRADESH   5.9   7.4  14.6  20.4  33.8  110.7  176.8
# ...

# %%
template = pn.template.FastListTemplate(
    title = 'Flood Dashboard',
    sidebar=[pn.pane.Markdown("#flood prediction"),
             pn.pane.Markdown("###This is te flood prediction page"),
             pn.pane.JPG('img.jpg', sizing_mode='scale_both'),
             pn.pane.Markdown("##settings"),
             month_slider],
    main=[pn.Row(pn.column(yaxis_co2,
                           co2_plot.panel(wdith=700), margin=(0,25)),
                 co2_table.panel(width=500)),
          pn.Row(pn.Coloumn(co2_vs_gdp_scatterplot.panel(width=600), margin=(0,25)),
                 pn.Coloumn(yaxis_co2_source_bar_plot.panel(width=600)))],
    accent_base_color="#88d8b0",
    header_background="#88d8b0",
)
# template.show()
template.servable();
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [22], line 7
#       1 template = pn.template.FastListTemplate(
#       2     title = 'Flood Dashboard',
#       3     sidebar=[pn.pane.Markdown("#flood prediction"),
#       4              pn.pane.Markdown("###This is te flood prediction page"),
#       5              pn.pane.JPG('img.jpg', sizing_mode='scale_both'),
#       6              pn.pane.Markdown("##settings"),
# ----> 7              month_slider],
#       8     main=[pn.Row(pn.column(yaxis_co2,
#       9                            co2_plot.panel(wdith=700), margin=(0,25)),
#      10                  co2_table.panel(width=500)),
#      11           pn.Row(pn.Coloumn(co2_vs_gdp_scatterplot.panel(width=600), margin=(0,25)),
#      12                  pn.Coloumn(yaxis_co2_source_bar_plot.panel(width=600)))],
#      13     accent_base_color="#88d8b0",
# ...
